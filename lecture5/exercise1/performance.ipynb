# %%
import matplotlib.pyplot as plt

file = "performance.dat"
data = open(file, "r").readlines()
n = [int(x.split()[0]) for x in data]
t = [float(x.split()[1]) for x in data]

plt.xlabel('n')
plt.ylabel('time in seconds')
plt.xlim(0, 16)
plt.plot(n, t, 'x')
